# %% [markdown]
#  <H1>My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __VijayKrishna__<br>I am currently student in GCT coimbatore

# %% [markdown]
# _I am interested in data science because i would like to find the patterns that are inside the data that i have and play with it to build some new stuffs._

# %% [markdown]
# ### i have assigned a variable "add" and to that variable i have given values as (5+20) and i am print the variable add

# %%
add=5+20
print(add)
# Out:
# 25

# %% [markdown]
# ###  Some type of Fruits:
#     1.Citrus fruits
#     2.Tropical and Exotic Fruits
#    - Citrus fruits:
#       |     oranges      |      grapefruits       |       mandarins      |     limes         |
#       |--------|----------|---------|------|
#       |<img src="https://5.imimg.com/data5/EE/ER/MY-27568370/fresh-orange-500x500.png" alt="Citurs fruits" title="orange" />|<img src="https://www.freepnglogos.com/uploads/grapes-png/grapes-dimidwa-12.png" alt="Citurs fruits" title="Mandarins" />|<img src="https://e7.pngegg.com/pngimages/364/914/png-clipart-mandarin-orange-tangerine-orange-natural-foods-food.png" alt="Citurs fruits" title="Mandarins" />|<img src="data:image/jpeg;base64,..." alt="Citurs fruits" title="limes" />|
#
#   ***
#    - Tropical and Exotic Fruits:
#       |Bananas|Mangos|
#       |-----------|-----------|
#       |<img src="data:image/jpeg;base64,..." alt="Tropical and Exotic fruits" title="Bananas" />|<img src="data:image/jpeg;base64,..." alt="Tropical and Exotic fruits" title="Mango"/>|
#
#
# ***
